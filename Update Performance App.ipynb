# %%
import pandas as pd
import requests
import yaml

# %%
SCData = pd.read_csv("Data Files//Indicator Data - Real - Annual.csv")
SCData.head(5)
# Out:
#         Key_CodePeriodDType          Key_CodePeriodFamilyGroupDType  \
# 0  C&L 012010-11Real_Annual  C&L 012010-11Family Group 4Real_Annual
# 1  C&L 012011-12Real_Annual  C&L 012011-12Family Group 4Real_Annual
# 2  C&L 012012-13Real_Annual  C&L 012012-13Family Group 4Real_Annual
# 3  C&L 012013-14Real_Annual  C&L 012013-14Family Group 4Real_Annual
# 4  C&L 012014-15Real_Annual  C&L 012014-15Family Group 4Real_Annual
#
#                    Key_CodePeriodLADType    Code LocalAuthority   Period  \
# 0  C&L 012010-11Aberdeen CityReal_Annual  C&L 01  Aberdeen City  2010-11
# 1  C&L 012011-12Aberdeen CityReal_Annual  C&L 01  Aberdeen City  2011-12
# 2  C&L 012012-13Aberdeen CityReal_Annual  C&L 01  Aberdeen City  2012-13
# 3  C&L 012013-14Aberdeen CityReal_Annual  C&L 01  Aberdeen City  2013-14
# 4  C&L 012014-15Aberdeen CityReal_Annual  C&L 01  Aberdeen City  2014-15
#
#     Value   Numerator  Denominator  FamilyRank  FamilyPct  ScotRank  ScotPct  \
# ...
